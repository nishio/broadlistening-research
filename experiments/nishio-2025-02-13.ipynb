# %%
import pandas as pd

# %%
data = pd.read_csv("results/hdbscan_cluster_labels.csv")
data
# Out:
#       data_index  cluster  probability  outlier_score
# 0              0       -1     0.000000       0.002165
# 1              1       -1     0.000000       0.014756
# 2              2       -1     0.000000       0.069300
# 3              3       -1     0.000000       0.022777
# 4              4       -1     0.000000       0.015186
# ...          ...      ...          ...            ...
# 9878        9878       24     0.957819       0.042181
# 9879        9879       -1     0.000000       0.004862
# 9880        9880       -1     0.000000       0.033825
# 9881        9881       -1     0.000000       0.012428
# 9882        9882       -1     0.000000       0.031422
#
# [9883 rows x 4 columns]

# %%
data["cluster"].unique().shape
# Out:
# (67,)

# %%
data = pd.read_csv("results/dataset_x_clusters.csv")
data
# Out:
#     cluster_id  size  avg_distance  max_distance   density data_index  \
# 0        144.0   6.0      0.462652      0.744075  2.161453     A144_0
# 1        144.0   6.0      0.462652      0.744075  2.161453     A144_1
# 2        144.0   6.0      0.462652      0.744075  2.161453     A144_2
# 3        144.0   6.0      0.462652      0.744075  2.161453     A144_3
# 4         89.0  12.0      0.514442      0.798871  1.943852      A89_0
# 5         89.0  12.0      0.514442      0.798871  1.943852      A89_1
# 6         89.0  12.0      0.514442      0.798871  1.943852      A89_2
# 7         89.0  12.0      0.514442      0.798871  1.943852      A89_3
# 8         89.0  12.0      0.514442      0.798871  1.943852      A89_4
# 9        171.0  14.0      0.567282      0.864550  1.762793     A171_0
# 10        91.0   8.0      0.577608      0.869514  1.731278      A91_0
# 11        91.0   8.0      0.577608      0.869514  1.731278      A91_1
# ...

# %%
data["cluster_id"].unique()  # wrong
# Out:
# array([144.,  89., 171.,  91.,  49.,  39.,  64., 172., 209., 121.])

# %%
data = pd.read_csv("results/metrics/kmeans_same_size_metrics.csv")
data
# Out:
#       cluster_id  size  avg_distance  max_distance   density
# 0              0     3      0.963091      1.011905  1.038324
# 1              1     4      0.805146      0.966258  1.242010
# 2              2     1      0.000000      0.000000  0.000000
# 3              3     7      0.831722      1.024176  1.202325
# 4              4     4      0.758722      0.879027  1.318006
# ...          ...   ...           ...           ...       ...
# 1221        1221     1      0.000000      0.000000  0.000000
# 1222        1222     1      0.000000      0.000000  0.000000
# 1223        1223     2      0.757487      0.757487  1.320154
# 1224        1224     5      0.800653      0.939078  1.248981
# 1225        1225     1      0.000000      0.000000  0.000000
#
# [1226 rows x 5 columns]

# %%
data["cluster_id"].unique().shape
# Out:
# (1226,)

# %%
data = pd.read_csv("results/kmeans_cluster_labels.csv")
data
# Out:
#                      arg-id          comment-id  \
# 0                      A0_0                   0
# 1                      A0_1                   0
# 2                      A1_0                   1
# 3                      A1_1                   1
# 4                      A1_2                   1
# ...                     ...                 ...
# 9878  A185001345000002997_2  185001345000002997
# 9879  A185001345000002999_0  185001345000002999
# 9880  A185001345000002999_1  185001345000002999
# 9881  A185001345000003000_0  185001345000003000
# 9882  A185001345000003000_1  185001345000003000
#
#                                                argument  cluster-id
# 0     生成AIは既存の著作物データを処理し出力するものであり、その出力は著作物の二次利用と見なされ...         487
# 1     著作権法は作者の内面の発露である著作物を保護し、文化的恩恵の維持と発展を求めるものである。著...         874
# 2     生成AIは、数式に基づくプログラムとアルゴリズムを用いてデジタル化された著作物データから特徴...         752
# 3     予測AIと生成AIの混同が懸念され、生成AIの技術的背景に関する説明が不十分であることが問題...        1162
# ...

# %%
data["cluster-id"].unique()
